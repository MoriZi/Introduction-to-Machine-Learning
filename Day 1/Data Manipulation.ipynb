# %% [markdown]
# <img src="./images/di.png" width="50" height="50" align="right"/>
#
# # Data Manipulation with Python

# %% [markdown]
# ## Learning Objectives
# *In this lesson, we will go over the following:*
#
# - Define what Pandas is and how it relates to data science.
# - Manipulate Pandas `DataFrames` and `Series`.
# - Filter and sort data using Pandas.
# - Manipulate `DataFrame` columns.
# - Know how to handle null and missing values.

# %% [markdown]
# ## Lesson Guide
#
# - [What Is Pandas?](#pandas)
# - [Reading Files, Selecting Columns, and Summarizing](#reading-files)
#     - [Exercise 1](#exercise-one)
#
#
# - [Filtering and Sorting](#filtering-and-sorting)
#     - [Exercise 2](#exercise-two)
#
#
# - [Renaming, Adding, and Removing Columns](#columns)
# - [Handling Missing Values](#missing-values)
#     - [Exercise 3](#exercise-three)
#
#
# - [Split-Apply-Combine](#split-apply-combine)
#     - [Exercise 4](#exercise-four)
#
#
# - [Selecting Multiple Columns and Filtering Rows](#multiple-columns)
# - [Joining (Merging) DataFrames](#joining-dataframes)
# - [OPTIONAL: Other Commonly Used Features](#other-features)
# - [OPTIONAL: Other Less Used Features of Pandas](#uncommon-features)
# - [Summary](#summary)

# %% [markdown]
# <img src="./images/pandas.jpeg" width="300"  align="center"/>

# %% [markdown]
# <a id="pandas"></a>
#
# ## What Is Pandas?
#
# - **Objective:** Define what Pandas is and how it relates to data science.
#
# Pandas is a Python library that primarily adds two new datatypes to Python: `DataFrame` and `Series`.
#
# - A `Series` is a sequence of items, where each item has a unique label (called an `index`).
# - A `DataFrame` is a table of data. Each row has a unique label (the `row index`), and each column has a unique label (the `column index`).
# - Note that each column in a `DataFrame` can be considered a `Series` (`Series` index).
#
# > Behind the scenes, these datatypes use the NumPy ("Numerical Python") library. NumPy primarily adds the `ndarray` (n-dimensional array) datatype to Pandas. An `ndarray` is similar to a Python list — it stores ordered data. However, it differs in three respects:
# > - Each element has the same datatype (typically fixed-size, e.g., a 32-bit integer).
# > - Elements are stored contiguously (immediately after each other) in memory for fast retrieval.
# > - The total size of an `ndarray` is fixed.
#
# > Storing `Series` and `DataFrame` data in `ndarray`s makes Pandas faster and uses less memory than standard Python datatypes. Many libraries (such as scikit-learn) accept `ndarray`s as input rather than Pandas datatypes, so we will frequently convert between them.

# %% [markdown]
# ## Why Pandas is so popular ?
# <img src="./images/pandas_stack.png" width="1000" align="center"/>

# %% [markdown]
# ## Using Pandas
#
# Pandas is frequently used in data science because it offers a large set of commonly used functions, is relatively fast, and has a large community. Because many data science libraries also use NumPy to manipulate data, you can easily transfer data between libraries (as we will often do in this class!).
#
# Pandas is a large library that typically takes a lot of practice to learn. It heavily overrides Python operators, resulting in odd-looking syntax. For example, given a `DataFrame` called `cars` which contains a column `mpg`, we might want to view all cars with mpg over 35. To do this, we might write: `cars[cars['mpg'] > 35]`. In standard Python, this would most likely give a syntax error. (**Challenge:** Using only built-in datatypes, can you define `cars` and `mpg` to make this expression valid?)
#
# Pandas also highly favors certain patterns of use. For example, looping through a `DataFrame` row by row is highly discouraged. Instead, Pandas favors using **vectorized functions** that operate column by column. (This is because each column is stored separately as an `ndarray`, and NumPy is optimized for operating on `ndarray`s.)
#
# Do not be discouraged if Pandas feels overwhelming. Gradually, as you use it, you will become familiar with which methods to use and the "Pandas way" of thinking about and manipulating data.

# %% [markdown]
# ### Class Methods and Attributes
#
# Pandas `DataFrame`s are Pandas class objects and therefore come with attributes and methods. To access these, follow the variable name with a dot. For example, given a `DataFrame` called `users`:
#
# ```
# - users.index       # accesses the `index` attribute -- note there are no parentheses. attributes are not callable
# - users.head()      # calls the `head` method (since there are open/closed parentheses)
# - users.head(10)    # calls the `head` method with parameter `10`, indicating the first 10 rows. this is the same as:
# - users.head(n=10)  # calls the `head` method, setting the named parameter `n` to have a value of `10`.
# ```
#
# We know that the `head` method accepts one parameter with an optional name of `n` because it is in the documentation for that method. Let's see how to view the documentation next.

# %% [markdown]
# ## First lets import Pandas

# %%
# %pip install pandas matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /Users/mzihayat/Library/Python/3.9/lib/python/site-packages (2.1.1)
# Requirement already satisfied: matplotlib in /Users/mzihayat/Library/Python/3.9/lib/python/site-packages (3.8.1)
# Requirement already satisfied: numpy>=1.22.4 in /Users/mzihayat/Library/Python/3.9/lib/python/site-packages (from pandas) (1.26.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/mzihayat/Library/Python/3.9/lib/python/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/mzihayat/Library/Python/3.9/lib/python/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/mzihayat/Library/Python/3.9/lib/python/site-packages (from pandas) (2023.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/mzihayat/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/mzihayat/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: pillow>=8 in /Users/mzihayat/Library/Python/3.9/lib/python/site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/mzihayat/Library/Python/3.9/lib/python/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: packaging>=20.0 in /Users/mzihayat/Library/Python/3.9/lib/python/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/mzihayat/Library/Python/3.9/lib/python/site-packages (from matplotlib) (4.43.1)
# Requirement already satisfied: cycler>=0.10 in /Users/mzihayat/Library/Python/3.9/lib/python/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/mzihayat/Library/Python/3.9/lib/python/site-packages (from matplotlib) (6.1.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/mzihayat/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.17.0)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.15.0)
# WARNING: You are using pip version 21.2.4; however, version 23.3.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load Pandas into Python
import pandas as pd
from matplotlib import pyplot as plt

# %matplotlib inline

# %% [markdown]
# <a id="reading-files"></a>
# ### Reading Files, Selecting Columns, and Summarizing

# %%
# using the read_csv method of pandas we read file 
users = pd.read_csv('./data/user.tbl', sep='|')

# %% [markdown]
# **Examine the users data.**

# %%
users                   # Print the first 30 and last 30 rows.
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
type(users)             # DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
# how to get the size of the dtaframe?
users.shape
# Out:
# (943, 5)

# %%
users.head(5)          # Print the first five rows.
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %%
users.head(10)          # Print the first 10 rows.
# Out:
#    user_id  age gender     occupation zip_code
# 0        1   24      M     technician    85711
# 1        2   53      F          other    94043
# 2        3   23      M         writer    32067
# 3        4   24      M     technician    43537
# 4        5   33      F          other    15213
# 5        6   42      M      executive    98101
# 6        7   57      M  administrator    91344
# 7        8   36      M  administrator    05201
# 8        9   29      M        student    01002
# 9       10   53      M         lawyer    90703

# %%
users.head()            # Print the last five rows.
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %%
users.tail()
# Out:
#      user_id  age gender     occupation zip_code
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841

# %%
 # The row index (aka "the row labels" — in this case integers)
users.index
# Out:
# RangeIndex(start=0, stop=943, step=1)

# %%
# Column names (which is "an index")
users.columns
# Out:
# Index(['user_id', 'age', 'gender', 'occupation', 'zip_code'], dtype='object')

# %%
# Datatypes of each column — each column is stored as an ndarray, which has a datatype
users.dtypes
# Out:
# user_id        int64
# age            int64
# gender        object
# occupation    object
# zip_code      object
# dtype: object

# %%
# Number of rows and columns
users.shape
# Out:
# (943, 5)

# %%
users.shape[0]
# Out:
# 943

# %%
# All values as a NumPy array
users.values
# Out:
# array([[1, 24, 'M', 'technician', '85711'],
#        [2, 53, 'F', 'other', '94043'],
#        [3, 23, 'M', 'writer', '32067'],
#        ...,
#        [941, 20, 'M', 'student', '97229'],
#        [942, 48, 'F', 'librarian', '78209'],
#        [943, 22, 'M', 'student', '77841']], dtype=object)

# %%
# Concise summary (including memory usage) — useful to quickly see if nulls exist
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 943 entries, 0 to 942
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     943 non-null    int64
#  1   age         943 non-null    int64
#  2   gender      943 non-null    object
#  3   occupation  943 non-null    object
#  4   zip_code    943 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 37.0+ KB

# %% [markdown]
# **Select or index data.**
#
# Pandas `DataFrame`s have structural similarities with Python-style lists and dictionaries.
# In the example below, we select a column of data using the name of the column in a similar manner to how we select a dictionary value with the dictionary key.

# %%
# Select a column — returns a Pandas Series (essentially an ndarray with an index)
users['gender']
# Out:
# 0      M
# 1      F
# 2      M
# 3      M
# 4      F
#       ..
# 938    F
# 939    M
# 940    M
# 941    F
# 942    M
# Name: gender, Length: 943, dtype: object

# %%
# DataFrame columns are Pandas Series.
type(users['age'])
# Out:
# pandas.core.series.Series

# %%
# Select one column using the DataFrame attribute.
users.gender
# While a useful shorthand, these attributes only exist
# if the column name has no punctuations or spaces.
# Out:
# 0      M
# 1      F
# 2      M
# 3      M
# 4      F
#       ..
# 938    F
# 939    M
# 940    M
# 941    F
# 942    M
# Name: gender, Length: 943, dtype: object

# %% [markdown]
# **Summarize (describe) the data.**<br>
# Pandas has a bunch of built-in methods to quickly summarize your data and provide you with a quick general understanding.

# %%
# Describe all numeric columns.
users.describe()
# Out:
#           user_id         age
# count  943.000000  943.000000
# mean   472.000000   34.051962
# std    272.364951   12.192740
# min      1.000000    7.000000
# 25%    236.500000   25.000000
# 50%    472.000000   31.000000
# 75%    707.500000   43.000000
# max    943.000000   73.000000

# %%
# Describe all columns, including non-numeric.
users.describe(include='all')
# Out:
#            user_id         age gender occupation zip_code
# count   943.000000  943.000000    943        943      943
# unique         NaN         NaN      2         21      795
# top            NaN         NaN      M    student    55414
# freq           NaN         NaN    670        196        9
# mean    472.000000   34.051962    NaN        NaN      NaN
# std     272.364951   12.192740    NaN        NaN      NaN
# min       1.000000    7.000000    NaN        NaN      NaN
# 25%     236.500000   25.000000    NaN        NaN      NaN
# 50%     472.000000   31.000000    NaN        NaN      NaN
# 75%     707.500000   43.000000    NaN        NaN      NaN
# max     943.000000   73.000000    NaN        NaN      NaN

# %%
# Describe a single column — recall that "users.gender" refers to a Series.
users.gender.describe()
# Out:
# count     943
# unique      2
# top         M
# freq      670
# Name: gender, dtype: object

# %%
# Calculate the mean of the ages.
users.age.mean()
# Out:
# 34.05196182396607

# %%
# Draw a histogram of a column (the distribution of ages).
users.age.hist();

# %% [markdown]
# **Count the number of occurrences of each value.**

# %%
users.gender.value_counts()  

# Most useful for categorical variables
# Out:
# gender
# M    670
# F    273
# Name: count, dtype: int64

# %%
# How many of each zip codes do we have? 
users.occupation.value_counts()
# Out:
# occupation
# student          196
# other            105
# educator          95
# administrator     79
# engineer          67
# programmer        66
# librarian         51
# writer            45
# executive         32
# scientist         31
# artist            28
# technician        27
# marketing         26
# entertainment     18
# healthcare        16
# retired           14
# lawyer            12
# salesman          12
# none               9
# homemaker          7
# doctor             7
# Name: count, dtype: int64

# %%
users.gender.value_counts()
# Out:
# gender
# M    670
# F    273
# Name: count, dtype: int64

# %%
users.occupation.value_counts().plot(kind='bar')     # Quick plot by category
# Out:
# <Axes: xlabel='occupation'>

# %%
# Can also be used with numeric variables
#   Try .sort_index() to sort by indices or .sort_values() to sort by counts.
users.age.value_counts()
# Out:
# age
# 30    39
# 25    38
# 22    37
# 28    36
# 27    35
#       ..
# 7      1
# 66     1
# 11     1
# 10     1
# 73     1
# Name: count, Length: 61, dtype: int64

# %%
users.age.value_counts().sort_index()
# Out:
# age
# 7     1
# 10    1
# 11    1
# 13    5
# 14    3
#      ..
# 66    1
# 68    2
# 69    2
# 70    3
# 73    1
# Name: count, Length: 61, dtype: int64

# %%
users.age.value_counts().sort_index().plot(kind='bar', figsize=(16,5));     # Bigger plot by increasing age
plt.xlabel('Age');
plt.ylabel('Number of users');
plt.title('Number of users per age');

# %% [markdown]
# # Excercise 1
# <img src="./images/hands_on.jpg" width="100" height="100" align="right"/>

# %%
# Read drinks.csv into a DataFrame called "drinks".
import pandas as pd
drinks = pd.read_csv('./data/drinks.csv')
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
drinks.shape
# Out:
# (193, 6)

# %%
# Print the head and the tail.
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
drinks.tail()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 188  Venezuela            333              100              3
# 189    Vietnam            111                2              1
# 190      Yemen              6                0              0
# 191     Zambia             32               19              4
# 192   Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 188                           7.7        SA
# 189                           2.0        AS
# 190                           0.1        AS
# 191                           2.5        AF
# 192                           4.7        AF

# %%
# Examine the default index, datatypes, and shape.
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
drinks.index
# Out:
# RangeIndex(start=0, stop=193, step=1)

# %%
# Print the beer_servings Series.
drinks.beer
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/gc/2wrphvw94cl1stzcrbvpd7kw0000gn/T/ipykernel_5717/392730101.py in ?()
# ----> 2 # Print the beer_servings Series.
#       3 drinks.beer
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'beer'

# %%
# Calculate the average beer_servings for the entire data set.
drinks.beer.mean()
# Out:
# 106.16062176165804

# %%
# Count the number of occurrences of each "continent" value and see if it looks correct.
drinks['continent'].value_counts()
# Out:
# continent
# AF    53
# EU    45
# AS    44
# NA    23
# OC    16
# SA    12
# Name: count, dtype: int64

# %% [markdown]
# <a id="filtering-and-sorting"></a>
# ### Filtering and Sorting
#
# <img src="./images/panda_sort.jpg" width="300" height="300" align="right"/>
#
#
#
# - **Objective:** Filter and sort data using Pandas.
#
# We can use simple operator comparisons on columns to extract relevant or drop irrelevant information.

# %% [markdown]
# **Logical filtering: Only show users with age < 20.**

# %%
# Create a Series of Booleans…
# In Pandas, this comparison is performed element-wise on each row of data.
young_bool = users.age < 20
young_bool
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 938    False
# 939    False
# 940    False
# 941    False
# 942    False
# Name: age, Length: 943, dtype: bool

# %%
users.age==14
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 938    False
# 939    False
# 940    False
# 941    False
# 942    False
# Name: age, Length: 943, dtype: bool

# %%
# …and use that Series to filter rows.
# In Pandas, indexing a DataFrame by a Series of Booleans only selects rows that are True in the Boolean.
users[users.age==14]
#users[young_bool]
# Out:
#      user_id  age gender occupation zip_code
# 205      206   14      F    student    53115
# 812      813   14      F    student    02136
# 886      887   14      F    student    27249

# %%
users['boolage']=users.age < 30
users.head(5)
# Out:
#    user_id  age gender  occupation zip_code  boolage
# 0        1   24      M  technician    85711     True
# 1        2   53      F       other    94043    False
# 2        3   23      M      writer    32067     True
# 3        4   24      M  technician    43537     True
# 4        5   33      F       other    15213    False

# %%
# Or, combine into a single step.
users[users.gender == "M"]
# Out:
#      user_id  age gender     occupation zip_code  boolage
# 0          1   24      M     technician    85711     True
# 2          3   23      M         writer    32067     True
# 3          4   24      M     technician    43537     True
# 5          6   42      M      executive    98101    False
# 6          7   57      M  administrator    91344    False
# ..       ...  ...    ...            ...      ...      ...
# 935      936   24      M          other    32789     True
# 936      937   48      M       educator    98072    False
# 939      940   32      M  administrator    02215    False
# 940      941   20      M        student    97229     True
# 942      943   22      M        student    77841     True
#
# [670 rows x 6 columns]

# %%
users.columns
# Out:
# Index(['user_id', 'age', 'gender', 'occupation', 'zip_code', 'boolage'], dtype='object')

# %%
users['is_young']=0

# %%
users.head()
# Out:
#    user_id  age gender  occupation zip_code  boolage  is_young
# 0        1   24      M  technician    85711     True         0
# 1        2   53      F       other    94043    False         0
# 2        3   23      M      writer    32067     True         0
# 3        4   24      M  technician    43537     True         0
# 4        5   33      F       other    15213    False         0

# %%
# Important: This creates a view of the original DataFrame, not a new DataFrame.
# If you alter this view (e.g., by storing it in a variable and altering that)
# You will alter only the slice of the DataFrame and not the actual DataFrame itself
# Here, notice that Pandas gives you a SettingWithCopyWarning to alert you of this.

# It is best practice to use .loc and .iloc instead of the syntax below

users_under20 = users[users.age < 20]   # To resolve this warning, copy the `DataFrame` using `.copy()`.

# %%
# Select one column from the filtered results.
users[users.age < 20].occupation
# Out:
# 29      student
# 35      student
# 51      student
# 56         none
# 66      student
#          ...
# 871     student
# 879     student
# 886     student
# 903     student
# 924    salesman
# Name: occupation, Length: 77, dtype: object

# %%
# value_counts of resulting Series
users[users.age < 20].occupation.value_counts()
# Out:
# occupation
# student          64
# other             4
# none              3
# entertainment     2
# writer            2
# artist            1
# salesman          1
# Name: count, dtype: int64

# %% [markdown]
# **Logical filtering with multiple conditions**

# %%
# Ampersand for `AND` condition. (This is a "bitwise" `AND`.)
# Important: You MUST put parentheses around each expression because `&` has a higher precedence than `<`.
users[(users.age < 20) & (users.gender=='M')]
# Out:
#      user_id  age gender     occupation zip_code  boolage  is_young
# 29        30    7      M        student    55436     True         0
# 56        57   16      M           none    84010     True         0
# 66        67   17      M        student    60402     True         0
# 67        68   19      M        student    22904     True         0
# 100      101   15      M        student    05146     True         0
# 109      110   19      M        student    77840     True         0
# 141      142   13      M          other    48118     True         0
# 178      179   15      M  entertainment    20755     True         0
# 220      221   19      M        student    20685     True         0
# 245      246   19      M        student    28734     True         0
# 256      257   17      M        student    77005     True         0
# 288      289   11      M           none    94619     True         0
# 290      291   19      M        student    44106     True         0
# 302      303   19      M        student    14853     True         0
# 319      320   19      M        student    24060     True         0
# 346      347   18      M        student    90210     True         0
# 366      367   17      M        student    37411     True         0
# 367      368   18      M        student    92113     True         0
# 374      375   17      M  entertainment    37777     True         0
# 392      393   19      M        student    83686     True         0
# 396      397   17      M        student    27514     True         0
# 424      425   19      M        student    58644     True         0
# 450      451   16      M        student    48446     True         0
# 452      453   18      M        student    06333     True         0
# 460      461   15      M        student    98102     True         0
# 470      471   10      M        student    77459     True         0
# 520      521   19      M        student    02146     True         0
# 527      528   18      M        student    55104     True         0
# 579      580   16      M        student    17961     True         0
# 581      582   17      M        student    93003     True         0
# 591      592   18      M        student    97520     True         0
# 618      619   17      M        student    44134     True         0
# 620      621   17      M        student    60402     True         0
# 623      624   19      M        student    30067     True         0
# 627      628   13      M           none    94306     True         0
# 631      632   18      M        student    55454     True         0
# 699      700   17      M        student    76309     True         0
# 709      710   19      M        student    92020     True         0
# 728      729   19      M        student    56567     True         0
# 746      747   19      M          other    93612     True         0
# 760      761   17      M        student    97302     True         0
# 816      817   19      M        student    60152     True         0
# 850      851   18      M          other    29646     True         0
# 862      863   17      M        student    60089     True         0
# 879      880   13      M        student    83702     True         0

# %%
# Pipe for `OR` condition. (This is a "bitwise" `OR`.)
# Important: You MUST put parentheses around each expression because `|` has a higher precedence than `<`.
users[((users.age < 20) | (users.age > 60))]
# Out:
#      user_id  age gender occupation zip_code  boolage  is_young
# 29        30    7      M    student    55436     True         0
# 56        57   16      M       none    84010     True         0
# 66        67   17      M    student    60402     True         0
# 67        68   19      M    student    22904     True         0
# 100      101   15      M    student    05146     True         0
# ..       ...  ...    ...        ...      ...      ...       ...
# 850      851   18      M      other    29646     True         0
# 857      858   63      M   educator    09645    False         0
# 862      863   17      M    student    60089     True         0
# 879      880   13      M    student    83702     True         0
# 933      934   61      M   engineer    22902    False         0
#
# [65 rows x 7 columns]

# %%
# Preferred alternative to multiple `OR` conditions

# users[(users['occupation']=='doctor') | (users['occupation']=='lawyer')]
users[users.occupation.isin(['doctor', 'lawyer', 'educator'])]
# Out:
#      user_id  age gender occupation zip_code  boolage  is_young
# 9         10   53      M     lawyer    90703    False         0
# 12        13   47      M   educator    29206    False         0
# 14        15   49      F   educator    97301    False         0
# 50        51   28      M   educator    16509     True         0
# 58        59   49      M   educator    08403    False         0
# ..       ...  ...    ...        ...      ...      ...       ...
# 908      909   50      F   educator    53171    False         0
# 930      931   60      M   educator    33556    False         0
# 931      932   58      M   educator    06437    False         0
# 934      935   42      M     doctor    66221    False         0
# 936      937   48      M   educator    98072    False         0
#
# [114 rows x 7 columns]

# %% [markdown]
# **Sorting**

# %%
# Sort a Series.
users.age.sort_values()
# Out:
# 29      7
# 470    10
# 288    11
# 879    13
# 608    13
#        ..
# 584    69
# 766    70
# 802    70
# 859    70
# 480    73
# Name: age, Length: 943, dtype: int64

# %%
# Sort a DataFrame by a single column.
users.sort_values('age')
# Out:
#      user_id  age gender     occupation zip_code  boolage  is_young
# 29        30    7      M        student    55436     True         0
# 470      471   10      M        student    77459     True         0
# 288      289   11      M           none    94619     True         0
# 879      880   13      M        student    83702     True         0
# 608      609   13      F        student    55106     True         0
# ..       ...  ...    ...            ...      ...      ...       ...
# 584      585   69      M      librarian    98501    False         0
# 766      767   70      M       engineer    00000    False         0
# 802      803   70      M  administrator    78212    False         0
# 859      860   70      F        retired    48322    False         0
# 480      481   73      M        retired    37771    False         0
#
# [943 rows x 7 columns]

# %%
# Use descending order instead.
users.sort_values('age', ascending=False)
# Out:
#      user_id  age gender     occupation zip_code  boolage  is_young
# 480      481   73      M        retired    37771    False         0
# 802      803   70      M  administrator    78212    False         0
# 766      767   70      M       engineer    00000    False         0
# 859      860   70      F        retired    48322    False         0
# 584      585   69      M      librarian    98501    False         0
# ..       ...  ...    ...            ...      ...      ...       ...
# 879      880   13      M        student    83702     True         0
# 608      609   13      F        student    55106     True         0
# 288      289   11      M           none    94619     True         0
# 470      471   10      M        student    77459     True         0
# 29        30    7      M        student    55436     True         0
#
# [943 rows x 7 columns]

# %%
# Sort by multiple columns.
users.sort_values(['occupation', 'age'])
# Out:
#      user_id  age gender     occupation zip_code  boolage  is_young
# 117      118   21      M  administrator    90210     True         0
# 179      180   22      F  administrator    60202     True         0
# 281      282   22      M  administrator    20057     True         0
# 316      317   22      M  administrator    13210     True         0
# 438      439   23      F  administrator    20817     True         0
# ..       ...  ...    ...            ...      ...      ...       ...
# 547      548   51      M         writer    95468    False         0
# 369      370   52      M         writer    08534    False         0
# 391      392   52      M         writer    59801    False         0
# 557      558   56      F         writer    63132    False         0
# 463      464   60      M         writer    94583    False         0
#
# [943 rows x 7 columns]

# %% [markdown]
# <a id="exercise-two"></a>
# ### Exercise 2
#
# <img src="./images/hands_on.jpg" width="100" height="100" align="right"/>
#
# Use the `drinks.csv` or `drinks` `DataFrame` from earlier to complete the following.

# %%
drinks.head(2)
# Out:
#        country  beer  spirit  wine  liters continent  cont_AS  cont_EU  \
# 0  Afghanistan   0.0       0     0     0.0        AS     True    False
# 1      Albania  89.0     132    54     4.9        EU    False     True
#
#    cont_NA  cont_OC  cont_SA beer_level
# 0    False    False    False        low
# 1    False    False    False        low

# %%
# Filter DataFrame to only include European countries.
eu_countries = drinks[drinks['continent'] == 'EU']

# %%
# Filter DataFrame to only include European countries with wine_servings > 300.
drinks[(drinks['continent'] == "EU") & (drinks['wine'] > 300)]
# Out:
#       country   beer  spirit  wine  liters continent  cont_AS  cont_EU  \
# 3     Andorra  245.0     138   312    12.4        EU    False     True
# 61     France  127.0     151   370    11.8        EU    False     True
# 136  Portugal  194.0      67   339    11.0        EU    False     True
#
#      cont_NA  cont_OC  cont_SA beer_level
# 3      False    False    False       high
# 61     False    False    False        med
# 136    False    False    False        med

# %%
# Calculate the average beer_servings for all of Europe.
drinks[(drinks['continent'] == 'EU')].beer.mean()
# Out:
# 193.77777777777777

# %%
# Determine which 10 countries have the highest total_litres_of_pure_alcohol.
drinks.sort_values('liters').tail(10)
# Out:
#                 country   beer  spirit  wine  liters continent  cont_AS  \
# 99           Luxembourg  236.0     133   271    11.4        EU    False
# 155            Slovakia  196.0     293   116    11.4        EU    False
# 81              Ireland  313.0     118   165    11.4        EU    False
# 141  Russian Federation  247.0     326    73    11.5        AS     True
# 61               France  127.0     151   370    11.8        EU    False
# 45       Czech Republic  361.0     170   134    11.8        EU    False
# 68              Grenada  199.0     438    28    11.9        NA    False
# 3               Andorra  245.0     138   312    12.4        EU    False
# 98            Lithuania  343.0     244    56    12.9        EU    False
# 15              Belarus  142.0     373    42    14.4        EU    False
#
#      cont_EU  cont_NA  cont_OC  cont_SA beer_level
# 99      True    False    False    False       high
# 155     True    False    False    False        med
# 81      True    False    False    False       high
# 141    False    False    False    False       high
# 61      True    False    False    False        med
# 45      True    False    False    False       high
# 68     False     True    False    False        med
# 3       True    False    False    False       high
# 98      True    False    False    False       high
# 15      True    False    False    False        med

# %% [markdown]
# <a id="columns"></a>
# ### Renaming, Adding, and Removing Columns
#
# <img src="./images/panda_api.jpeg" width="300" height="300" align="right"/>
#
# - **Objective:** Manipulate `DataFrame` columns.

# %%
drinks = pd.read_csv('./data/drinks.csv')

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
# Rename one or more columns in a single output using value mapping.
drinks.rename(columns={'beer_servings':'beer', 'wine_servings':'wine','spirit_servings':'spirit'})
# Out:
#          country  beer  spirit  wine  total_litres_of_pure_alcohol continent
# 0    Afghanistan     0       0     0                           0.0        AS
# 1        Albania    89     132    54                           4.9        EU
# 2        Algeria    25       0    14                           0.7        AF
# 3        Andorra   245     138   312                          12.4        EU
# 4         Angola   217      57    45                           5.9        AF
# ..           ...   ...     ...   ...                           ...       ...
# 188    Venezuela   333     100     3                           7.7        SA
# 189      Vietnam   111       2     1                           2.0        AS
# 190        Yemen     6       0     0                           0.1        AS
# 191       Zambia    32      19     4                           2.5        AF
# 192     Zimbabwe    64      18     4                           4.7        AF
#
# [193 rows x 6 columns]

# %%
drinks.head(2)
# Out:
#        country  beer  spirit  wine  liters continent
# 0  Afghanistan     0       0     0     0.0        AS
# 1      Albania    89     132    54     4.9        EU

# %%
# Rename one or more columns in the original DataFrame.
drinks.rename(columns={'beer_servings':'beer', 'wine_servings':'wine'
                       ,'spirit_servings':'spirit','total_litres_of_pure_alcohol':'liters'}, inplace=True)

# %%
drinks.head(2)
# Out:
#        country  beer  spirit  wine  liters continent
# 0  Afghanistan     0       0     0     0.0        AS
# 1      Albania    89     132    54     4.9        EU

# %% [markdown]
# **Easy Column Operations**<br>
# Rather than having to reference indexes and create for loops to do column-wise operations, Pandas is smart and knows that when we add columns together we want to add the values in each row together.

# %%
# Add a new column as a function of existing columns.
drinks['servings'] = drinks.beer + drinks.spirit + drinks.wine
drinks['mL'] = drinks.liters * 1000
drinks['beer_ratio'] = drinks.beer / drinks.liters

# %%
drinks.head()
# Out:
#        country  beer  spirit  wine  liters continent  servings       mL  \
# 0  Afghanistan     0       0     0     0.0        AS         0      0.0
# 1      Albania    89     132    54     4.9        EU       275   4900.0
# 2      Algeria    25       0    14     0.7        AF        39    700.0
# 3      Andorra   245     138   312    12.4        EU       695  12400.0
# 4       Angola   217      57    45     5.9        AF       319   5900.0
#
#    beer_ratio
# 0         NaN
# 1   18.163265
# 2   35.714286
# 3   19.758065
# 4   36.779661

# %% [markdown]
# **Removing Columns**

# %%
# Drop multiple columns.
drinks.drop(['mL', 'servings', 'beer_ratio'], axis=1)
# Out:
#          country  beer  spirit  wine  liters continent
# 0    Afghanistan     0       0     0     0.0        AS
# 1        Albania    89     132    54     4.9        EU
# 2        Algeria    25       0    14     0.7        AF
# 3        Andorra   245     138   312    12.4        EU
# 4         Angola   217      57    45     5.9        AF
# ..           ...   ...     ...   ...     ...       ...
# 188    Venezuela   333     100     3     7.7        SA
# 189      Vietnam   111       2     1     2.0        AS
# 190        Yemen     6       0     0     0.1        AS
# 191       Zambia    32      19     4     2.5        AF
# 192     Zimbabwe    64      18     4     4.7        AF
#
# [193 rows x 6 columns]

# %%
drinks.head(3)
# Out:
#        country  beer  spirit  wine  liters continent  servings      mL  \
# 0  Afghanistan     0       0     0     0.0        AS         0     0.0
# 1      Albania    89     132    54     4.9        EU       275  4900.0
# 2      Algeria    25       0    14     0.7        AF        39   700.0
#
#    beer_ratio
# 0         NaN
# 1   18.163265
# 2   35.714286

# %%
# Drop on the original DataFrame rather than returning a new one.
drinks.drop(['mL', 'servings', 'beer_ratio'], axis=1, inplace=True)

# %%
drinks.head(3)
# Out:
#        country  beer  spirit  wine  liters continent
# 0  Afghanistan     0       0     0     0.0        AS
# 1      Albania    89     132    54     4.9        EU
# 2      Algeria    25       0    14     0.7        AF

# %% [markdown]
# <a id="missing-values"></a>
# ### Handling Missing Values
#
#
# <img src="./images/panda_analysis.jpeg" width="300" height="300" align="right"/>
#
# - **Objective:** Know how to handle null and missing values.
#
# Sometimes, values will be missing from the source data or as a byproduct of manipulations. It is very important to detect missing data. Missing data can:
#
# - Make the entire row ineligible to be training data for a model.
# - Hint at data-collection errors.
# - Indicate improper conversion or manipulation.
# - Actually not be missing — it sometimes means "zero," "false," "not applicable," or "entered an empty string."
#
# For example, a `.csv` file might have a missing value in some data fields:
#
# ```
# tool_name,material,cost
# hammer,wood,8
# chainsaw,,
# wrench,metal,5
# ```
#
# When this data is imported, "null" values will be stored in the second row (in the "material" and "cost" columns).
#
# > In Pandas, a "null" value is either `None` or `np.NaN` (Not a Number). Many fixed-size numeric datatypes (such as integers) do not have a way of representing `np.NaN`. So, numeric columns will be promoted to floating-point datatypes that do support it. For example, when importing the `.csv` file above:
#
# > - **For the second row:** `None` will be stored in the "material" column and `np.NaN` will be stored in the "cost" column. The entire "cost" column (stored as a single `ndarray`) must be stored as floating-point values to accommodate the `np.NaN`, even though an integer `8` is in the first row.

# %%
# Missing values are usually excluded in calculations by default.
drinks.continent.value_counts()              # Excludes missing values in the calculation
# Out:
# continent
# AF    53
# EU    45
# AS    44
# OC    16
# SA    12
# Name: count, dtype: int64

# %%
# Includes missing values
drinks.continent.value_counts(dropna=False)
# Out:
# continent
# AF     53
# EU     45
# AS     44
# NaN    23
# OC     16
# SA     12
# Name: count, dtype: int64

# %%
# Count the missing values — sum() works because True is 1 and False is 0.
drinks.continent.isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# Name: continent, Length: 193, dtype: bool

# %%
# Find missing values in a Series.
# True if missing, False if not missing
drinks.continent.isnull().sum()
# Out:
# 23

# %%
drinks[drinks.continent.isnull()]
# Out:
#                           country  beer  spirit  wine  liters continent  \
# 5               Antigua & Barbuda   102     128    45     4.9       NaN
# 11                        Bahamas   122     176    51     6.3       NaN
# 14                       Barbados   143     173    36     6.3       NaN
# 17                         Belize   263     114     8     6.8       NaN
# 32                         Canada   240     122   100     8.2       NaN
# 41                     Costa Rica   149      87    11     4.4       NaN
# 43                           Cuba    93     137     5     4.2       NaN
# 50                       Dominica    52     286    26     6.6       NaN
# 51             Dominican Republic   193     147     9     6.2       NaN
# 54                    El Salvador    52      69     2     2.2       NaN
# 68                        Grenada   199     438    28    11.9       NaN
# 69                      Guatemala    53      69     2     2.2       NaN
# 73                          Haiti     1     326     1     5.9       NaN
# 74                       Honduras    69      98     2     3.0       NaN
# 84                        Jamaica    82      97     9     3.4       NaN
# 109                        Mexico   238      68     5     5.5       NaN
# 122                     Nicaragua    78     118     1     3.5       NaN
# 130                        Panama   285     104    18     7.2       NaN
# 143             St. Kitts & Nevis   194     205    32     7.7       NaN
# 144                     St. Lucia   171     315    71    10.1       NaN
# 145  St. Vincent & the Grenadines   120     221    11     6.3       NaN
# 174             Trinidad & Tobago   197     156     7     6.4       NaN
# 184                           USA   249     158    84     8.7       NaN
#
#      servings       mL  beer_ratio
# 5         275   4900.0   20.816327
# 11        349   6300.0   19.365079
# 14        352   6300.0   22.698413
# 17        385   6800.0   38.676471
# 32        462   8200.0   29.268293
# 41        247   4400.0   33.863636
# 43        235   4200.0   22.142857
# 50        364   6600.0    7.878788
# 51        349   6200.0   31.129032
# 54        123   2200.0   23.636364
# 68        665  11900.0   16.722689
# 69        124   2200.0   24.090909
# 73        328   5900.0    0.169492
# 74        169   3000.0   23.000000
# 84        188   3400.0   24.117647
# 109       311   5500.0   43.272727
# 122       197   3500.0   22.285714
# 130       407   7200.0   39.583333
# 143       431   7700.0   25.194805
# 144       557  10100.0   16.930693
# 145       352   6300.0   19.047619
# 174       360   6400.0   30.781250
# 184       491   8700.0   28.620690

# %%
# Only show rows where continent is not missing.
drinks[drinks.continent.isnull()]
#drinks[drinks.continent.notnull()]
# Out:
#                           country  beer  spirit  wine  liters continent
# 5               Antigua & Barbuda   102     128    45     4.9       NaN
# 11                        Bahamas   122     176    51     6.3       NaN
# 14                       Barbados   143     173    36     6.3       NaN
# 17                         Belize   263     114     8     6.8       NaN
# 32                         Canada   240     122   100     8.2       NaN
# 41                     Costa Rica   149      87    11     4.4       NaN
# 43                           Cuba    93     137     5     4.2       NaN
# 50                       Dominica    52     286    26     6.6       NaN
# 51             Dominican Republic   193     147     9     6.2       NaN
# 54                    El Salvador    52      69     2     2.2       NaN
# 68                        Grenada   199     438    28    11.9       NaN
# 69                      Guatemala    53      69     2     2.2       NaN
# 73                          Haiti     1     326     1     5.9       NaN
# 74                       Honduras    69      98     2     3.0       NaN
# 84                        Jamaica    82      97     9     3.4       NaN
# 109                        Mexico   238      68     5     5.5       NaN
# 122                     Nicaragua    78     118     1     3.5       NaN
# 130                        Panama   285     104    18     7.2       NaN
# 143             St. Kitts & Nevis   194     205    32     7.7       NaN
# 144                     St. Lucia   171     315    71    10.1       NaN
# 145  St. Vincent & the Grenadines   120     221    11     6.3       NaN
# 174             Trinidad & Tobago   197     156     7     6.4       NaN
# 184                           USA   249     158    84     8.7       NaN

# %% [markdown]
# **Find missing values in a `DataFrame`.**

# %%
# Count the missing values in each column — remember by default, axis=0.
print((drinks.isnull().sum()))
# Out:
# country        0
# beer           0
# spirit         0
# wine           0
# liters         0
# continent     23
# servings       0
# mL             0
# beer_ratio    13
# dtype: int64

# %%
drinks.isnull().sum().plot(kind='bar');         # visually
plt.title('Number of null values per column');

# %% [markdown]
# **Dropping Missing Values**

# %%
drinks.shape
# Out:
# (193, 6)

# %%
# Drop a row if ANY values are missing from any column — can be dangerous!
drinks.dropna()
# Out:
#          country  beer  spirit  wine  liters continent
# 0    Afghanistan     0       0     0     0.0        AS
# 1        Albania    89     132    54     4.9        EU
# 2        Algeria    25       0    14     0.7        AF
# 3        Andorra   245     138   312    12.4        EU
# 4         Angola   217      57    45     5.9        AF
# ..           ...   ...     ...   ...     ...       ...
# 188    Venezuela   333     100     3     7.7        SA
# 189      Vietnam   111       2     1     2.0        AS
# 190        Yemen     6       0     0     0.1        AS
# 191       Zambia    32      19     4     2.5        AF
# 192     Zimbabwe    64      18     4     4.7        AF
#
# [170 rows x 6 columns]

# %%
# Drop a row only if ALL values are missing.
drinks.dropna(how='all')
# Out:
#          country  beer  spirit  wine  liters continent
# 0    Afghanistan     0       0     0     0.0        AS
# 1        Albania    89     132    54     4.9        EU
# 2        Algeria    25       0    14     0.7        AF
# 3        Andorra   245     138   312    12.4        EU
# 4         Angola   217      57    45     5.9        AF
# ..           ...   ...     ...   ...     ...       ...
# 188    Venezuela   333     100     3     7.7        SA
# 189      Vietnam   111       2     1     2.0        AS
# 190        Yemen     6       0     0     0.1        AS
# 191       Zambia    32      19     4     2.5        AF
# 192     Zimbabwe    64      18     4     4.7        AF
#
# [193 rows x 6 columns]

# %% [markdown]
# **Filling Missing Values**<br>
# You may have noticed that the continent North America (NA) does not appear in the `continent` column. Pandas read in the original data and saw "NA", thought it was a missing value, and converted it to a `NaN`, missing value.

# %%
# Fill in missing values with "NA" — this is dangerous to do without manually verifying them!
drinks.continent.fillna(value='NA')
# Out:
# 0      AS
# 1      EU
# 2      AF
# 3      EU
# 4      AF
#        ..
# 188    SA
# 189    AS
# 190    AS
# 191    AF
# 192    AF
# Name: continent, Length: 193, dtype: object

# %%
# Modifies "drinks" in-place
drinks.continent.fillna(value='NA', inplace=True)

# %% [markdown]
# <a id="exercise-three"></a>
# ### Exercise 3
#
#
# <img src="./images/hands_on.jpg" width="100" height="100" align="right"/>

# %%
# Read ufo.csv into a DataFrame called "ufo".
ufo= pd.read_csv('./data/ufo.csv')
ufo.head(2)
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00

# %%
# Check the shape of the DataFrame.
ufo.shape
# Out:
# (80543, 5)

# %%
# What are the three most common colors reported?
ufo['Colors Reported'].value_counts().head(3)
# Out:
# Colors Reported
# ORANGE    5216
# RED       4809
# GREEN     1897
# Name: count, dtype: int64

# %%
# Rename any columns with spaces so that they don't contain spaces.
ufo.rename(columns={'Colors Reported':'Colors', 'Shape Reported':'Shape'}, inplace=True)

# %%
ufo
# Out:
#                      Time                  City    Colors     Shape State
# 0     1930-06-01 22:00:00                Ithaca       NaN  TRIANGLE    NY
# 1     1930-06-30 20:00:00           Willingboro       NaN     OTHER    NJ
# 2     1931-02-15 14:00:00               Holyoke       NaN      OVAL    CO
# 3     1931-06-01 13:00:00               Abilene       NaN      DISK    KS
# 4     1933-04-18 19:00:00  New York Worlds Fair       NaN     LIGHT    NY
# ...                   ...                   ...       ...       ...   ...
# 80538 2014-09-04 23:20:00                Neligh       NaN    CIRCLE    NE
# 80539 2014-09-05 01:14:00          Uhrichsville       NaN     LIGHT    OH
# 80540 2014-09-05 02:40:00                Tucson  RED BLUE       NaN    AZ
# 80541 2014-09-05 03:43:00           Orland park       RED     LIGHT    IL
# 80542 2014-09-05 05:30:00              Loughman       NaN     LIGHT    FL
#
# [80543 rows x 5 columns]

# %%
# For reports in VA, what's the most common city?
ufo[ufo.State=='VA'].value_counts().head(1)
# Out:
# Time                 City        Colors  Shape     State
# 2014-08-09 23:15:00  Dunnsville  ORANGE  FIREBALL  VA       2
# Name: count, dtype: int64

# %%
# Print a DataFrame containing only reports from Arlington, VA.
ufo[(ufo.State=='VA') & (ufo.City=='Arlington')]
# Out:
#                      Time       City      Colors      Shape State
# 202   1952-07-13 21:00:00  Arlington       GREEN       OVAL    VA
# 6300  1990-05-05 21:40:00  Arlington         NaN    CHEVRON    VA
# 10278 1997-05-27 15:30:00  Arlington         NaN       DISK    VA
# 14527 1999-09-10 21:41:00  Arlington         NaN      OTHER    VA
# 17984 2000-11-19 22:00:00  Arlington         RED       DISK    VA
# 21201 2002-01-07 17:45:00  Arlington       GREEN   FIREBALL    VA
# 22633 2002-07-26 01:15:00  Arlington         NaN      LIGHT    VA
# 22780 2002-08-07 21:00:00  Arlington         NaN      LIGHT    VA
# 25066 2003-06-01 22:34:00  Arlington         NaN      CIGAR    VA
# 27398 2003-12-13 02:00:00  Arlington         NaN    VARIOUS    VA
# 30608 2004-10-09 22:30:00  Arlington         NaN     CIRCLE    VA
# 31316 2004-12-13 00:30:00  Arlington         NaN  FORMATION    VA
# 35787 2006-03-15 22:30:00  Arlington         NaN      LIGHT    VA
# 37036 2006-08-01 22:00:00  Arlington         NaN   TRIANGLE    VA
# 39673 2007-04-07 18:45:00  Arlington         NaN      LIGHT    VA
# 41083 2007-08-15 01:30:00  Arlington         NaN      FLASH    VA
# 44562 2008-06-06 21:55:00  Arlington         NaN   TRIANGLE    VA
# 45450 2008-08-02 20:30:00  Arlington         NaN       OVAL    VA
# 48679 2009-04-24 17:45:00  Arlington         NaN     SPHERE    VA
# 54613 2010-09-17 19:00:00  Arlington         NaN      LIGHT    VA
# 54944 2010-10-12 19:00:00  Arlington         NaN     SPHERE    VA
# 70462 2013-06-25 23:00:00  Arlington         NaN   FIREBALL    VA
# 72856 2013-09-26 21:20:00  Arlington         RED     SPHERE    VA
# 73408 2013-10-19 00:17:00  Arlington         NaN     CIRCLE    VA
# 73747 2013-11-01 22:42:00  Arlington         NaN      LIGHT    VA
# 76144 2014-02-21 14:30:00  Arlington         NaN      CIGAR    VA
# 76325 2014-03-01 20:00:00  Arlington         NaN        NaN    VA
# 76337 2014-03-01 23:30:00  Arlington         NaN  FORMATION    VA
# 77807 2014-05-24 22:30:00  Arlington  RED ORANGE      LIGHT    VA
# 79122 2014-07-07 21:00:00  Arlington         NaN     CIRCLE    VA

# %%
# Count the number of missing values in each column.
ufo.isna().sum()
# Out:
# Time          0
# City         51
# Colors    63509
# Shape      8402
# State         0
# dtype: int64

# %%
# How many rows remain if you drop all rows with any missing values?
print('the original size:', ufo.shape[0])
ufo.dropna().shape[0]
# Out:
# the original size: 80543
# 15509

# %% [markdown]
# <a id="split-apply-combine"></a>
# ### Split-Apply-Combine
#
# <img src="./images/pandas_tool.jpg" width="300" height="300" align="right"/>
#
# Split-apply-combine is a pattern for analyzing data. Suppose we want to find mean beer consumption per country. Then:
#
# - **Split:** We group data by continent.
# - **Apply:** For each group, we apply the `mean()` function to find the average beer consumption.
# - **Combine:** We now combine the continent names with the `mean()`s to produce a summary of our findings.

# %%
drinks.head(3)
# Out:
#        country  beer  spirit  wine  liters continent
# 0  Afghanistan     0       0     0     0.0        AS
# 1      Albania    89     132    54     4.9        EU
# 2      Algeria    25       0    14     0.7        AF

# %%
# For each continent, calculate the mean beer servings.
drinks.groupby('continent').beer.mean()
# Out:
# continent
# AF     61.471698
# AS     37.045455
# EU    193.777778
# OC     89.687500
# SA    175.083333
# Name: beer, dtype: float64

# %%
# For each continent, describe beer servings.
drinks.groupby('continent').beer.describe()
# Out:
#            count        mean        std   min     25%    50%     75%    max
# continent
# AF          53.0   61.471698  80.557816   0.0   15.00   32.0   76.00  376.0
# AS          44.0   37.045455  49.469725   0.0    4.25   17.5   60.50  247.0
# EU          45.0  193.777778  99.631569   0.0  127.00  219.0  270.00  361.0
# OC          16.0   89.687500  96.641412   0.0   21.00   52.5  125.75  306.0
# SA          12.0  175.083333  65.242845  93.0  129.50  162.5  198.00  333.0

# %%
# For each continent, describe all numeric columns.
drinks.groupby('continent').describe()
# Out:
#            beer                                                             \
#           count        mean        std   min     25%    50%     75%    max
# continent
# AF         53.0   61.471698  80.557816   0.0   15.00   32.0   76.00  376.0
# AS         44.0   37.045455  49.469725   0.0    4.25   17.5   60.50  247.0
# EU         45.0  193.777778  99.631569   0.0  127.00  219.0  270.00  361.0
# OC         16.0   89.687500  96.641412   0.0   21.00   52.5  125.75  306.0
# SA         12.0  175.083333  65.242845  93.0  129.50  162.5  198.00  333.0
#
#           spirit              ...    wine        liters                      \
#            count        mean  ...     75%    max  count      mean       std
# continent                     ...
# AF          53.0   16.339623  ...   13.00  233.0   53.0  3.007547  2.647557
# AS          44.0   60.840909  ...    8.00  123.0   44.0  2.170455  2.770239
# EU          45.0  132.555556  ...  195.00  370.0   45.0  8.617778  3.358455
# OC          16.0   58.437500  ...   23.25  212.0   16.0  3.381250  3.345688
# SA          12.0  114.750000  ...   98.50  221.0   12.0  6.308333  1.531166
#
#
#            min   25%    50%     75%   max
# continent
# AF         0.0  0.70   2.30   4.700   9.1
# AS         0.0  0.10   1.20   2.425  11.5
# EU         0.0  6.60  10.00  10.900  14.4
# OC         0.0  1.00   1.75   6.150  10.4
# SA         3.8  5.25   6.85   7.375   8.3
#
# [5 rows x 32 columns]

# %%
# For each continent, count the number of rows.
print((drinks.continent.value_counts()))   # should be the same
# Out:
# continent
# AF    53
# EU    45
# AS    44
# OC    16
# SA    12
# Name: count, dtype: int64

# %% [markdown]
# <a id="exercise-four"></a>
# ### Exercise 4 : TAKE HOME
#
# <img src="./images/hands_on.jpg" width="100" height="100" align="right"/>
#
# Use the "users" `DataFrame` or "users" file in the Data folder to complete the following.

# %%
users.head(2)
# Out:
#    user_id  age gender  occupation zip_code  boolage  is_young
# 0        1   24      M  technician    85711     True         0
# 1        2   53      F       other    94043    False         0

# %%
# For each occupation in "users", count the number of occurrences.
# Out:
# occupation
# administrator     79
# artist            28
# doctor             7
# educator          95
# engineer          67
# entertainment     18
# executive         32
# healthcare        16
# homemaker          7
# lawyer            12
# librarian         51
# marketing         26
# none               9
# other            105
# programmer        66
# retired           14
# salesman          12
# scientist         31
# student          196
# technician        27
# writer            45
# Name: user_id, dtype: int64

# %%
# For each occupation, calculate the mean age.
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %%
# For each occupation, calculate the minimum and maximum ages.
# Out:
#                min       mean  max
# occupation
# administrator   21  38.746835   70
# artist          19  31.392857   48
# doctor          28  43.571429   64
# educator        23  42.010526   63
# engineer        22  36.388060   70
# entertainment   15  29.222222   50
# executive       22  38.718750   69
# healthcare      22  41.562500   62
# homemaker       20  32.571429   50
# lawyer          21  36.750000   53
# librarian       23  40.000000   69
# marketing       24  37.615385   55
# none            11  26.555556   55
# other           13  34.523810   64
# programmer      20  33.121212   63
# retired         51  63.071429   73
# salesman        18  35.666667   66
# scientist       23  35.548387   55
# student          7  22.081633   42
# technician      21  33.148148   55
# writer          18  36.311111   60

# %%
# For each combination of occupation and gender, calculate the mean age.

# %% [markdown]
# ----

# %% [markdown]
# <a id="multiple-columns"></a>
# ## Selecting Multiple Columns and Filtering Rows

# %%
ufo.head()
# Out:
#                  Time                  City Colors     Shape State
# 0 1930-06-01 22:00:00                Ithaca    NaN  TRIANGLE    NY
# 1 1930-06-30 20:00:00           Willingboro    NaN     OTHER    NJ
# 2 1931-02-15 14:00:00               Holyoke    NaN      OVAL    CO
# 3 1931-06-01 13:00:00               Abilene    NaN      DISK    KS
# 4 1933-04-18 19:00:00  New York Worlds Fair    NaN     LIGHT    NY

# %%
# Or, combine into a single step (this is a Python list inside of the Python index operator!).
ufo[['City', 'State']]
# Out:
#                        City State
# 0                    Ithaca    NY
# 1               Willingboro    NJ
# 2                   Holyoke    CO
# 3                   Abilene    KS
# 4      New York Worlds Fair    NY
# ...                     ...   ...
# 80538                Neligh    NE
# 80539          Uhrichsville    OH
# 80540                Tucson    AZ
# 80541           Orland park    IL
# 80542              Loughman    FL
#
# [80543 rows x 2 columns]

# %% [markdown]
# **Use `loc` to select columns by name.**

# %%
# "loc" locates the values from the first parameter (colon means "all rows"), and the column "City".
ufo.loc[:, 'City']
# Out:
# 0                      Ithaca
# 1                 Willingboro
# 2                     Holyoke
# 3                     Abilene
# 4        New York Worlds Fair
#                  ...
# 80538                  Neligh
# 80539            Uhrichsville
# 80540                  Tucson
# 80541             Orland park
# 80542                Loughman
# Name: City, Length: 80543, dtype: object

# %%
# Select two columns.
ufo.loc[:, ['City', 'State']]
# Out:
#                        City State
# 0                    Ithaca    NY
# 1               Willingboro    NJ
# 2                   Holyoke    CO
# 3                   Abilene    KS
# 4      New York Worlds Fair    NY
# ...                     ...   ...
# 80538                Neligh    NE
# 80539          Uhrichsville    OH
# 80540                Tucson    AZ
# 80541           Orland park    IL
# 80542              Loughman    FL
#
# [80543 rows x 2 columns]

# %%
# Select a range of columns — unlike Python ranges, Pandas index ranges INCLUDE the final column in the range.
ufo.loc[:, 'City':'Shape']
# Out:
#                        City    Colors     Shape
# 0                    Ithaca       NaN  TRIANGLE
# 1               Willingboro       NaN     OTHER
# 2                   Holyoke       NaN      OVAL
# 3                   Abilene       NaN      DISK
# 4      New York Worlds Fair       NaN     LIGHT
# ...                     ...       ...       ...
# 80538                Neligh       NaN    CIRCLE
# 80539          Uhrichsville       NaN     LIGHT
# 80540                Tucson  RED BLUE       NaN
# 80541           Orland park       RED     LIGHT
# 80542              Loughman       NaN     LIGHT
#
# [80543 rows x 3 columns]

# %%
# "loc" can also filter rows by "name" (the index).
# Row 0, all columns
ufo.loc[:, :'City']
# Out:
#                      Time                  City
# 0     1930-06-01 22:00:00                Ithaca
# 1     1930-06-30 20:00:00           Willingboro
# 2     1931-02-15 14:00:00               Holyoke
# 3     1931-06-01 13:00:00               Abilene
# 4     1933-04-18 19:00:00  New York Worlds Fair
# ...                   ...                   ...
# 80538 2014-09-04 23:20:00                Neligh
# 80539 2014-09-05 01:14:00          Uhrichsville
# 80540 2014-09-05 02:40:00                Tucson
# 80541 2014-09-05 03:43:00           Orland park
# 80542 2014-09-05 05:30:00              Loughman
#
# [80543 rows x 2 columns]

# %%
# Rows 0/1/2, all columns
ufo.loc[0:2, :]
# Out:
#                  Time         City Colors     Shape State
# 0 1930-06-01 22:00:00       Ithaca    NaN  TRIANGLE    NY
# 1 1930-06-30 20:00:00  Willingboro    NaN     OTHER    NJ
# 2 1931-02-15 14:00:00      Holyoke    NaN      OVAL    CO

# %%
# Rows 0/1/2, range of columns
ufo.loc[0:2, 'City':'State']
# Out:
#           City Colors     Shape State
# 0       Ithaca    NaN  TRIANGLE    NY
# 1  Willingboro    NaN     OTHER    NJ
# 2      Holyoke    NaN      OVAL    CO

# %% [markdown]
# <a id="joining-dataframes"></a>
# ### Joining (Merging) `DataFrames`
#
#
# <img src="./images/panda_science.jpeg" width="300" align="right"/>

# %%
import pandas as pd
movie_cols = ['movie_ID', 'title', 'release_date']
u_item = './data/movies.tbl'
movies = pd.read_csv(u_item, sep='|', header=None, names=movie_cols, usecols=[0, 1, 2], encoding='latin-1')
movies.head()
# Out:
#    movie_ID              title release_date
# 0         1   Toy Story (1995)  01-Jan-1995
# 1         2   GoldenEye (1995)  01-Jan-1995
# 2         3  Four Rooms (1995)  01-Jan-1995
# 3         4  Get Shorty (1995)  01-Jan-1995
# 4         5     Copycat (1995)  01-Jan-1995

# %%
rating_cols = ['user_id', 'movie_id', 'rating', 'timestamp']
ratings_filename = './data/movie_ratings.tsv'

ratings = pd.read_csv(ratings_filename, sep='\t', header=None, names=rating_cols)
ratings.head()
# Out:
#    user_id  movie_id  rating  timestamp
# 0      196       242       3  881250949
# 1      186       302       3  891717742
# 2       22       377       1  878887116
# 3      244        51       2  880606923
# 4      166       346       1  886397596

# %%
# Merge "movies" and "ratings" (inner join on "movie_id").
movie_ratings = pd.merge(movies, ratings, left_on='movie_ID', right_on='movie_id')
movie_ratings.head()
# Out:
#    movie_ID             title release_date  user_id  movie_id  rating  \
# 0         1  Toy Story (1995)  01-Jan-1995      308         1       4
# 1         1  Toy Story (1995)  01-Jan-1995      287         1       5
# 2         1  Toy Story (1995)  01-Jan-1995      148         1       4
# 3         1  Toy Story (1995)  01-Jan-1995      280         1       4
# 4         1  Toy Story (1995)  01-Jan-1995       66         1       3
#
#    timestamp
# 0  887736532
# 1  875334088
# 2  877019411
# 3  891700426
# 4  883601324

# %%
print(movies.shape)
print(ratings.shape)
print(movie_ratings.shape)
# Out:
# (1682, 3)
# (100000, 4)
# (100000, 7)

# %% [markdown]
# ## How to export your file?

# %%
movie_ratings.to_csv('new_movies.csv')

# %% [markdown]
# ### More Details about Merging
# https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html

# %% [markdown]
# ## Pandas CheatSheet
# https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf

# %% [markdown]
# <a id="other-features"></a>
# ### OPTIONAL: Other Commonly Used Features

# %%
# Apply an arbitrary function to each value of a Pandas column, storing the result in a new column.
users['under30'] = users.age.apply(lambda age: age < 30)

# %%
# Apply an arbitrary function to each row of a DataFrame, storing the result in a new column.
#  (Remember that, by default, axis=0. Since we want to go row by row, we set axis=1.)
users['under30male'] = users.apply(lambda row: row.age < 30 and row.gender == 'M', axis=1)

# %%
# Map existing values to a different set of values.
users['is_male'] = users.gender.map({'F':0, 'M':1})

# %%
# Replace all instances of a value in a column (must match entire value).
ufo.State.replace('Fl', 'FL', inplace=True)

# %%
# String methods are accessed via "str".
ufo.State.str.upper()                               # Converts to upper case
# checks for a substring
ufo['Colors Reported'].str.contains('RED', na='False')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 80538    False
# 80539    False
# 80540     True
# 80541     True
# 80542    False
# Name: Colors Reported, Length: 80543, dtype: object

# %%
# Convert a string to the datetime format (this is often slow — consider doing it in the "read_csv()" method.)
ufo['Time'] = pd.to_datetime(ufo.Time)
ufo.Time.dt.hour                        # Datetime format exposes convenient attributes
(ufo.Time.max() - ufo.Time.min()).days  # Also allows you to do datetime "math"
# Out:
# 30776

# %%
# Set and then remove an index.
ufo.set_index('Time', inplace=True)
ufo.reset_index(inplace=True)

# %%
# Change the datatype of a column.
drinks['beer'] = drinks.beer.astype('float')

# %%
# Create dummy variables for "continent" and exclude first dummy column.
continent_dummies = pd.get_dummies(drinks.continent, prefix='cont').iloc[:, 1:]

# %%
# Concatenate two DataFrames (axis=0 for rows, axis=1 for columns).
drinks = pd.concat([drinks, continent_dummies], axis=1)

# %% [markdown]
# <a id="uncommon-features"></a>
# ### OPTIONAL: Other Less-Used Features of Pandas

# %%
# Detecting duplicate rows
users.duplicated()          # True if a row is identical to a previous row
users.duplicated().sum()    # Count of duplicates
users[users.duplicated()]   # Only show duplicates
users.drop_duplicates()     # Drop duplicate rows
users.age.duplicated()      # Check a single column for duplicates
users.duplicated(['age', 'gender', 'zip_code']).sum()   # Specify columns for finding duplicates
# Out:
# 13

# %%
# Convert a range of values into descriptive groups.
drinks['beer_level'] = 'low'    # Initially set all values to "low"
drinks.loc[drinks.beer.between(101, 200), 'beer_level'] = 'med'     # Change 101-200 to "med"
drinks.loc[drinks.beer.between(201, 400), 'beer_level'] = 'high'    # Change 201-400 to "high"

# %%
# Display a cross-tabulation of two Series.
pd.crosstab(drinks.continent, drinks.beer_level)
# Out:
# beer_level  high  low  med
# continent
# AF             4   45    4
# AS             1   40    3
# EU            24    9   12
# NA             5    8   10
# OC             3   11    2
# SA             3    1    8

# %%
# Convert "beer_level" into the "category" datatype.
drinks['beer_level'] = pd.Categorical(drinks.beer_level, categories=['low', 'med', 'high'])
drinks.sort_values('beer_level')   # Sorts by the categorical ordering (low to high)
# Out:
#               country   beer  spirit  wine  liters continent  cont_AS  \
# 0         Afghanistan    0.0       0     0     0.0        AS     True
# 102          Malaysia   13.0       4     0     0.3        AS     True
# 103          Maldives    0.0       0     0     0.0        AS     True
# 104              Mali    5.0       1     1     0.6        AF    False
# 106  Marshall Islands    0.0       0     0     0.0        OC    False
# ..                ...    ...     ...   ...     ...       ...      ...
# 17             Belize  263.0     114     8     6.8        NA    False
# 121       New Zealand  203.0      79   175     9.3        OC    False
# 16            Belgium  295.0      84   212    10.5        EU    False
# 117           Namibia  376.0       3     1     6.8        AF    False
# 120       Netherlands  251.0      88   190     9.4        EU    False
#
#      cont_EU  cont_NA  cont_OC  cont_SA beer_level
# 0      False    False    False    False        low
# 102    False    False    False    False        low
# 103    False    False    False    False        low
# 104    False    False    False    False        low
# 106    False    False     True    False        low
# ..       ...      ...      ...      ...        ...
# 17     False     True    False    False       high
# 121    False    False     True    False       high
# 16      True    False    False    False       high
# 117    False    False    False    False       high
# 120     True    False    False    False       high
#
# [193 rows x 12 columns]

# %%
# Limit which rows are read when reading in a file — useful for large files!
pd.read_csv('./data/drinks.csv', nrows=10)           # Only read first 10 rows
pd.read_csv('./data/drinks.csv', skiprows=[1, 2])    # Skip the first two rows of data
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# 0              Algeria             25                0             14
# 1              Andorra            245              138            312
# 2               Angola            217               57             45
# 3    Antigua & Barbuda            102              128             45
# 4            Argentina            193               25            221
# ..                 ...            ...              ...            ...
# 186          Venezuela            333              100              3
# 187            Vietnam            111                2              1
# 188              Yemen              6                0              0
# 189             Zambia             32               19              4
# 190           Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.7        AF
# 1                            12.4        EU
# 2                             5.9        AF
# 3                             4.9       NaN
# 4                             8.3        SA
# ..                            ...       ...
# 186                           7.7        SA
# 187                           2.0        AS
# 188                           0.1        AS
# 189                           2.5        AF
# 190                           4.7        AF
#
# [191 rows x 6 columns]

# %%
# Write a DataFrame out to a .csv
drinks.to_csv('drinks_updated.csv')                 # Index is used as first column
drinks.to_csv('drinks_updated.csv', index=False)    # Ignore index

# %%
# Create a DataFrame from a dictionary.
pd.DataFrame({'capital':['Montgomery', 'Juneau', 'Phoenix'], 'state':['AL', 'AK', 'AZ']})
# Out:
#       capital state
# 0  Montgomery    AL
# 1      Juneau    AK
# 2     Phoenix    AZ

# %%
# Create a DataFrame from a list of lists.
pd.DataFrame([['Montgomery', 'AL'], ['Juneau', 'AK'], ['Phoenix', 'AZ']], columns=['capital', 'state'])
# Out:
#       capital state
# 0  Montgomery    AL
# 1      Juneau    AK
# 2     Phoenix    AZ

# %%
# Randomly sample a DataFrame.
import numpy as np
mask = np.random.rand(len(drinks)) < 0.66   # Create a Series of Booleans
train = drinks[mask]                        # Will contain around 66% of the rows
test = drinks[~mask]                        # Will contain the remaining rows

# %%
# Change the maximum number of rows and columns printed ('None' means unlimited).
pd.set_option('max_rows', None)     # Default is 60 rows
pd.set_option('max_columns', None)  # Default is 20 columns
print(drinks)
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# /Users/mzihayat/VSC/Introduction-to-Machine-Learning/Day 1/Data Manipulation.ipynb Cell 172 line 2
#       <a href='vscode-notebook-cell:/Users/mzihayat/VSC/Introduction-to-Machine-Learning/Day%201/Data%20Manipulation.ipynb#Y334sZmlsZQ%3D%3D?line=0'>1</a> # Change the maximum number of rows and columns printed ('None' means unlimited).
# ----> <a href='vscode-notebook-cell:/Users/mzihayat/VSC/Introduction-to-Machine-Learning/Day%201/Data%20Manipulation.ipynb#Y334sZmlsZQ%3D%3D?line=1'>2</a> pd.set_option('max_rows', None)     # Default is 60 rows
#       <a href='vscode-notebook-cell:/Users/mzihayat/VSC/Introduction-to-Machine-Learning/Day%201/Data%20Manipulation.ipynb#Y334sZmlsZQ%3D%3D?line=2'>3</a> pd.set_option('max_columns', None)  # Default is 20 columns
#       <a href='vscode-notebook-cell:/Users/mzihayat/VSC/Introduction-to-Machine-Learning/Day%201/Data%20Manipulation.ipynb#Y334sZmlsZQ%3D%3D?line=3'>4</a> print(drinks)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/_config/config.py:272, in CallableDynamicDoc.__call__(self, *args, **kwds)
#     271 def __call__(self, *args, **kwds) -> T:
# --> 272     return self.__func__(*args, **kwds)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/_config/config.py:167, in _set_option(*args, **kwargs)
#     164     raise TypeError(f'_set_option() got an unexpected keyword argument "{kwarg}"')
#     166 for k, v in zip(args[::2], args[1::2]):
# --> 167     key = _get_single_key(k, silent)
#     169     o = _get_registered_option(key)
#     170     if o and o.validator:
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/_config/config.py:134, in _get_single_key(pat, silent)
#     132     raise OptionError(f"No such keys(s): {repr(pat)}")
#     133 if len(keys) > 1:
# --> 134     raise OptionError("Pattern matched multiple keys")
#     135 key = keys[0]
#     137 if not silent:
#
# OptionError: 'Pattern matched multiple keys'

# %%
# Reset options to defaults.
pd.reset_option('max_rows')
pd.reset_option('max_columns')

# %%
# Change the options temporarily (settings are restored when you exit the "with" block).
with pd.option_context('max_rows', None, 'max_columns', None):
    print(drinks)
# Out:
#                           country   beer  spirit  wine  liters continent  \
# 0                     Afghanistan    0.0       0     0     0.0        AS
# 1                         Albania   89.0     132    54     4.9        EU
# 2                         Algeria   25.0       0    14     0.7        AF
# 3                         Andorra  245.0     138   312    12.4        EU
# 4                          Angola  217.0      57    45     5.9        AF
# 5               Antigua & Barbuda  102.0     128    45     4.9        NA
# 6                       Argentina  193.0      25   221     8.3        SA
# 7                         Armenia   21.0     179    11     3.8        EU
# 8                       Australia  261.0      72   212    10.4        OC
# 9                         Austria  279.0      75   191     9.7        EU
# 10                     Azerbaijan   21.0      46     5     1.3        EU
# 11                        Bahamas  122.0     176    51     6.3        NA
# 12                        Bahrain   42.0      63     7     2.0        AS
# 13                     Bangladesh    0.0       0     0     0.0        AS
# 14                       Barbados  143.0     173    36     6.3        NA
# 15                        Belarus  142.0     373    42    14.4        EU
# 16                        Belgium  295.0      84   212    10.5        EU
# 17                         Belize  263.0     114     8     6.8        NA
# 18                          Benin   34.0       4    13     1.1        AF
# 19                         Bhutan   23.0       0     0     0.4        AS
# 20                        Bolivia  167.0      41     8     3.8        SA
# 21             Bosnia-Herzegovina   76.0     173     8     4.6        EU
# 22                       Botswana  173.0      35    35     5.4        AF
# 23                         Brazil  245.0     145    16     7.2        SA
# 24                         Brunei   31.0       2     1     0.6        AS
# 25                       Bulgaria  231.0     252    94    10.3        EU
# 26                   Burkina Faso   25.0       7     7     4.3        AF
# 27                        Burundi   88.0       0     0     6.3        AF
# 28                  Cote d'Ivoire   37.0       1     7     4.0        AF
# 29                     Cabo Verde  144.0      56    16     4.0        AF
# 30                       Cambodia   57.0      65     1     2.2        AS
# 31                       Cameroon  147.0       1     4     5.8        AF
# 32                         Canada  240.0     122   100     8.2        NA
# 33       Central African Republic   17.0       2     1     1.8        AF
# 34                           Chad   15.0       1     1     0.4        AF
# 35                          Chile  130.0     124   172     7.6        SA
# 36                          China   79.0     192     8     5.0        AS
# 37                       Colombia  159.0      76     3     4.2        SA
# 38                        Comoros    1.0       3     1     0.1        AF
# 39                          Congo   76.0       1     9     1.7        AF
# 40                   Cook Islands    0.0     254    74     5.9        OC
# 41                     Costa Rica  149.0      87    11     4.4        NA
# 42                        Croatia  230.0      87   254    10.2        EU
# 43                           Cuba   93.0     137     5     4.2        NA
# 44                         Cyprus  192.0     154   113     8.2        EU
# 45                 Czech Republic  361.0     170   134    11.8        EU
# 46                    North Korea    0.0       0     0     0.0        AS
# 47                       DR Congo   32.0       3     1     2.3        AF
# 48                        Denmark  224.0      81   278    10.4        EU
# 49                       Djibouti   15.0      44     3     1.1        AF
# 50                       Dominica   52.0     286    26     6.6        NA
# 51             Dominican Republic  193.0     147     9     6.2        NA
# 52                        Ecuador  162.0      74     3     4.2        SA
# 53                          Egypt    6.0       4     1     0.2        AF
# 54                    El Salvador   52.0      69     2     2.2        NA
# 55              Equatorial Guinea   92.0       0   233     5.8        AF
# 56                        Eritrea   18.0       0     0     0.5        AF
# 57                        Estonia  224.0     194    59     9.5        EU
# 58                       Ethiopia   20.0       3     0     0.7        AF
# 59                           Fiji   77.0      35     1     2.0        OC
# 60                        Finland  263.0     133    97    10.0        EU
# 61                         France  127.0     151   370    11.8        EU
# 62                          Gabon  347.0      98    59     8.9        AF
# 63                         Gambia    8.0       0     1     2.4        AF
# 64                        Georgia   52.0     100   149     5.4        EU
# 65                        Germany  346.0     117   175    11.3        EU
# 66                          Ghana   31.0       3    10     1.8        AF
# 67                         Greece  133.0     112   218     8.3        EU
# 68                        Grenada  199.0     438    28    11.9        NA
# 69                      Guatemala   53.0      69     2     2.2        NA
# 70                         Guinea    9.0       0     2     0.2        AF
# 71                  Guinea-Bissau   28.0      31    21     2.5        AF
# 72                         Guyana   93.0     302     1     7.1        SA
# 73                          Haiti    1.0     326     1     5.9        NA
# 74                       Honduras   69.0      98     2     3.0        NA
# 75                        Hungary  234.0     215   185    11.3        EU
# 76                        Iceland  233.0      61    78     6.6        EU
# 77                          India    9.0     114     0     2.2        AS
# 78                      Indonesia    5.0       1     0     0.1        AS
# 79                           Iran    0.0       0     0     0.0        AS
# 80                           Iraq    9.0       3     0     0.2        AS
# 81                        Ireland  313.0     118   165    11.4        EU
# 82                         Israel   63.0      69     9     2.5        AS
# 83                          Italy   85.0      42   237     6.5        EU
# 84                        Jamaica   82.0      97     9     3.4        NA
# 85                          Japan   77.0     202    16     7.0        AS
# 86                         Jordan    6.0      21     1     0.5        AS
# 87                     Kazakhstan  124.0     246    12     6.8        AS
# 88                          Kenya   58.0      22     2     1.8        AF
# 89                       Kiribati   21.0      34     1     1.0        OC
# 90                         Kuwait    0.0       0     0     0.0        AS
# 91                     Kyrgyzstan   31.0      97     6     2.4        AS
# 92                           Laos   62.0       0   123     6.2        AS
# 93                         Latvia  281.0     216    62    10.5        EU
# 94                        Lebanon   20.0      55    31     1.9        AS
# 95                        Lesotho   82.0      29     0     2.8        AF
# 96                        Liberia   19.0     152     2     3.1        AF
# 97                          Libya    0.0       0     0     0.0        AF
# 98                      Lithuania  343.0     244    56    12.9        EU
# 99                     Luxembourg  236.0     133   271    11.4        EU
# 100                    Madagascar   26.0      15     4     0.8        AF
# 101                        Malawi    8.0      11     1     1.5        AF
# 102                      Malaysia   13.0       4     0     0.3        AS
# 103                      Maldives    0.0       0     0     0.0        AS
# 104                          Mali    5.0       1     1     0.6        AF
# 105                         Malta  149.0     100   120     6.6        EU
# 106              Marshall Islands    0.0       0     0     0.0        OC
# 107                    Mauritania    0.0       0     0     0.0        AF
# 108                     Mauritius   98.0      31    18     2.6        AF
# 109                        Mexico  238.0      68     5     5.5        NA
# 110                    Micronesia   62.0      50    18     2.3        OC
# 111                        Monaco    0.0       0     0     0.0        EU
# 112                      Mongolia   77.0     189     8     4.9        AS
# 113                    Montenegro   31.0     114   128     4.9        EU
# 114                       Morocco   12.0       6    10     0.5        AF
# 115                    Mozambique   47.0      18     5     1.3        AF
# 116                       Myanmar    5.0       1     0     0.1        AS
# 117                       Namibia  376.0       3     1     6.8        AF
# 118                         Nauru   49.0       0     8     1.0        OC
# 119                         Nepal    5.0       6     0     0.2        AS
# 120                   Netherlands  251.0      88   190     9.4        EU
# 121                   New Zealand  203.0      79   175     9.3        OC
# 122                     Nicaragua   78.0     118     1     3.5        NA
# 123                         Niger    3.0       2     1     0.1        AF
# 124                       Nigeria   42.0       5     2     9.1        AF
# 125                          Niue  188.0     200     7     7.0        OC
# 126                        Norway  169.0      71   129     6.7        EU
# 127                          Oman   22.0      16     1     0.7        AS
# 128                      Pakistan    0.0       0     0     0.0        AS
# 129                         Palau  306.0      63    23     6.9        OC
# 130                        Panama  285.0     104    18     7.2        NA
# 131              Papua New Guinea   44.0      39     1     1.5        OC
# 132                      Paraguay  213.0     117    74     7.3        SA
# 133                          Peru  163.0     160    21     6.1        SA
# 134                   Philippines   71.0     186     1     4.6        AS
# 135                        Poland  343.0     215    56    10.9        EU
# 136                      Portugal  194.0      67   339    11.0        EU
# 137                         Qatar    1.0      42     7     0.9        AS
# 138                   South Korea  140.0      16     9     9.8        AS
# 139                       Moldova  109.0     226    18     6.3        EU
# 140                       Romania  297.0     122   167    10.4        EU
# 141            Russian Federation  247.0     326    73    11.5        AS
# 142                        Rwanda   43.0       2     0     6.8        AF
# 143             St. Kitts & Nevis  194.0     205    32     7.7        NA
# 144                     St. Lucia  171.0     315    71    10.1        NA
# 145  St. Vincent & the Grenadines  120.0     221    11     6.3        NA
# 146                         Samoa  105.0      18    24     2.6        OC
# 147                    San Marino    0.0       0     0     0.0        EU
# 148           Sao Tome & Principe   56.0      38   140     4.2        AF
# 149                  Saudi Arabia    0.0       5     0     0.1        AS
# 150                       Senegal    9.0       1     7     0.3        AF
# 151                        Serbia  283.0     131   127     9.6        EU
# 152                    Seychelles  157.0      25    51     4.1        AF
# 153                  Sierra Leone   25.0       3     2     6.7        AF
# 154                     Singapore   60.0      12    11     1.5        AS
# 155                      Slovakia  196.0     293   116    11.4        EU
# 156                      Slovenia  270.0      51   276    10.6        EU
# 157               Solomon Islands   56.0      11     1     1.2        OC
# 158                       Somalia    0.0       0     0     0.0        AF
# 159                  South Africa  225.0      76    81     8.2        AF
# 160                         Spain  284.0     157   112    10.0        EU
# 161                     Sri Lanka   16.0     104     0     2.2        AS
# 162                         Sudan    8.0      13     0     1.7        AF
# 163                      Suriname  128.0     178     7     5.6        SA
# 164                     Swaziland   90.0       2     2     4.7        AF
# 165                        Sweden  152.0      60   186     7.2        EU
# 166                   Switzerland  185.0     100   280    10.2        EU
# 167                         Syria    5.0      35    16     1.0        AS
# 168                    Tajikistan    2.0      15     0     0.3        AS
# 169                      Thailand   99.0     258     1     6.4        AS
# 170                     Macedonia  106.0      27    86     3.9        EU
# 171                   Timor-Leste    1.0       1     4     0.1        AS
# 172                          Togo   36.0       2    19     1.3        AF
# 173                         Tonga   36.0      21     5     1.1        OC
# 174             Trinidad & Tobago  197.0     156     7     6.4        NA
# 175                       Tunisia   51.0       3    20     1.3        AF
# 176                        Turkey   51.0      22     7     1.4        AS
# 177                  Turkmenistan   19.0      71    32     2.2        AS
# 178                        Tuvalu    6.0      41     9     1.0        OC
# 179                        Uganda   45.0       9     0     8.3        AF
# 180                       Ukraine  206.0     237    45     8.9        EU
# 181          United Arab Emirates   16.0     135     5     2.8        AS
# 182                United Kingdom  219.0     126   195    10.4        EU
# 183                      Tanzania   36.0       6     1     5.7        AF
# 184                           USA  249.0     158    84     8.7        NA
# 185                       Uruguay  115.0      35   220     6.6        SA
# 186                    Uzbekistan   25.0     101     8     2.4        AS
# 187                       Vanuatu   21.0      18    11     0.9        OC
# 188                     Venezuela  333.0     100     3     7.7        SA
# 189                       Vietnam  111.0       2     1     2.0        AS
# 190                         Yemen    6.0       0     0     0.1        AS
# 191                        Zambia   32.0      19     4     2.5        AF
# 192                      Zimbabwe   64.0      18     4     4.7        AF
#
#      cont_AS  cont_EU  cont_NA  cont_OC  cont_SA beer_level
# 0          1        0        0        0        0        low
# 1          0        1        0        0        0        low
# 2          0        0        0        0        0        low
# 3          0        1        0        0        0       high
# 4          0        0        0        0        0       high
# 5          0        0        1        0        0        med
# 6          0        0        0        0        1        med
# 7          0        1        0        0        0        low
# 8          0        0        0        1        0       high
# 9          0        1        0        0        0       high
# 10         0        1        0        0        0        low
# 11         0        0        1        0        0        med
# 12         1        0        0        0        0        low
# 13         1        0        0        0        0        low
# 14         0        0        1        0        0        med
# 15         0        1        0        0        0        med
# 16         0        1        0        0        0       high
# 17         0        0        1        0        0       high
# 18         0        0        0        0        0        low
# 19         1        0        0        0        0        low
# 20         0        0        0        0        1        med
# 21         0        1        0        0        0        low
# 22         0        0        0        0        0        med
# 23         0        0        0        0        1       high
# 24         1        0        0        0        0        low
# 25         0        1        0        0        0       high
# 26         0        0        0        0        0        low
# 27         0        0        0        0        0        low
# 28         0        0        0        0        0        low
# 29         0        0        0        0        0        med
# 30         1        0        0        0        0        low
# 31         0        0        0        0        0        med
# 32         0        0        1        0        0       high
# 33         0        0        0        0        0        low
# 34         0        0        0        0        0        low
# 35         0        0        0        0        1        med
# 36         1        0        0        0        0        low
# 37         0        0        0        0        1        med
# 38         0        0        0        0        0        low
# 39         0        0        0        0        0        low
# 40         0        0        0        1        0        low
# 41         0        0        1        0        0        med
# 42         0        1        0        0        0       high
# 43         0        0        1        0        0        low
# 44         0        1        0        0        0        med
# 45         0        1        0        0        0       high
# 46         1        0        0        0        0        low
# 47         0        0        0        0        0        low
# 48         0        1        0        0        0       high
# 49         0        0        0        0        0        low
# 50         0        0        1        0        0        low
# 51         0        0        1        0        0        med
# 52         0        0        0        0        1        med
# 53         0        0        0        0        0        low
# 54         0        0        1        0        0        low
# 55         0        0        0        0        0        low
# 56         0        0        0        0        0        low
# 57         0        1        0        0        0       high
# 58         0        0        0        0        0        low
# 59         0        0        0        1        0        low
# 60         0        1        0        0        0       high
# 61         0        1        0        0        0        med
# 62         0        0        0        0        0       high
# 63         0        0        0        0        0        low
# 64         0        1        0        0        0        low
# 65         0        1        0        0        0       high
# 66         0        0        0        0        0        low
# 67         0        1        0        0        0        med
# 68         0        0        1        0        0        med
# 69         0        0        1        0        0        low
# 70         0        0        0        0        0        low
# 71         0        0        0        0        0        low
# 72         0        0        0        0        1        low
# 73         0        0        1        0        0        low
# 74         0        0        1        0        0        low
# 75         0        1        0        0        0       high
# 76         0        1        0        0        0       high
# 77         1        0        0        0        0        low
# 78         1        0        0        0        0        low
# 79         1        0        0        0        0        low
# 80         1        0        0        0        0        low
# 81         0        1        0        0        0       high
# 82         1        0        0        0        0        low
# 83         0        1        0        0        0        low
# 84         0        0        1        0        0        low
# 85         1        0        0        0        0        low
# 86         1        0        0        0        0        low
# 87         1        0        0        0        0        med
# 88         0        0        0        0        0        low
# 89         0        0        0        1        0        low
# 90         1        0        0        0        0        low
# 91         1        0        0        0        0        low
# 92         1        0        0        0        0        low
# 93         0        1        0        0        0       high
# 94         1        0        0        0        0        low
# 95         0        0        0        0        0        low
# 96         0        0        0        0        0        low
# 97         0        0        0        0        0        low
# 98         0        1        0        0        0       high
# 99         0        1        0        0        0       high
# 100        0        0        0        0        0        low
# 101        0        0        0        0        0        low
# 102        1        0        0        0        0        low
# 103        1        0        0        0        0        low
# 104        0        0        0        0        0        low
# 105        0        1        0        0        0        med
# 106        0        0        0        1        0        low
# 107        0        0        0        0        0        low
# 108        0        0        0        0        0        low
# 109        0        0        1        0        0       high
# 110        0        0        0        1        0        low
# 111        0        1        0        0        0        low
# 112        1        0        0        0        0        low
# 113        0        1        0        0        0        low
# 114        0        0        0        0        0        low
# 115        0        0        0        0        0        low
# 116        1        0        0        0        0        low
# 117        0        0        0        0        0       high
# 118        0        0        0        1        0        low
# 119        1        0        0        0        0        low
# 120        0        1        0        0        0       high
# 121        0        0        0        1        0       high
# 122        0        0        1        0        0        low
# 123        0        0        0        0        0        low
# 124        0        0        0        0        0        low
# 125        0        0        0        1        0        med
# 126        0        1        0        0        0        med
# 127        1        0        0        0        0        low
# 128        1        0        0        0        0        low
# 129        0        0        0        1        0       high
# 130        0        0        1        0        0       high
# 131        0        0        0        1        0        low
# 132        0        0        0        0        1       high
# 133        0        0        0        0        1        med
# 134        1        0        0        0        0        low
# 135        0        1        0        0        0       high
# 136        0        1        0        0        0        med
# 137        1        0        0        0        0        low
# 138        1        0        0        0        0        med
# 139        0        1        0        0        0        med
# 140        0        1        0        0        0       high
# 141        1        0        0        0        0       high
# 142        0        0        0        0        0        low
# 143        0        0        1        0        0        med
# 144        0        0        1        0        0        med
# 145        0        0        1        0        0        med
# 146        0        0        0        1        0        med
# 147        0        1        0        0        0        low
# 148        0        0        0        0        0        low
# 149        1        0        0        0        0        low
# 150        0        0        0        0        0        low
# 151        0        1        0        0        0       high
# 152        0        0        0        0        0        med
# 153        0        0        0        0        0        low
# 154        1        0        0        0        0        low
# 155        0        1        0        0        0        med
# 156        0        1        0        0        0       high
# 157        0        0        0        1        0        low
# 158        0        0        0        0        0        low
# 159        0        0        0        0        0       high
# 160        0        1        0        0        0       high
# 161        1        0        0        0        0        low
# 162        0        0        0        0        0        low
# 163        0        0        0        0        1        med
# 164        0        0        0        0        0        low
# 165        0        1        0        0        0        med
# 166        0        1        0        0        0        med
# 167        1        0        0        0        0        low
# 168        1        0        0        0        0        low
# 169        1        0        0        0        0        low
# 170        0        1        0        0        0        med
# 171        1        0        0        0        0        low
# 172        0        0        0        0        0        low
# 173        0        0        0        1        0        low
# 174        0        0        1        0        0        med
# 175        0        0        0        0        0        low
# 176        1        0        0        0        0        low
# 177        1        0        0        0        0        low
# 178        0        0        0        1        0        low
# 179        0        0        0        0        0        low
# 180        0        1        0        0        0       high
# 181        1        0        0        0        0        low
# 182        0        1        0        0        0       high
# 183        0        0        0        0        0        low
# 184        0        0        1        0        0       high
# 185        0        0        0        0        1        med
# 186        1        0        0        0        0        low
# 187        0        0        0        1        0        low
# 188        0        0        0        0        1       high
# 189        1        0        0        0        0        med
# 190        1        0        0        0        0        low
# 191        0        0        0        0        0        low
# 192        0        0        0        0        0        low

# %% [markdown]
# <a id="summary"></a>
# ### Summary
#
# Believe it or not, we've only barely touched the surface of everything that Pandas offers. Don't worry if you don't remember most of it — for now, just knowing what exists is key. Remember that the more you use Pandas to manipulate data, the more of these functions you will take interest in, look up, and remember.
#
# In this notebook, the most important things to familiarize yourself with are the basics:
# - Manipulating `DataFrames` and `Series`
# - Filtering columns and rows
# - Handling missing values
# - Split-apply-combine (this one takes some practice!)
